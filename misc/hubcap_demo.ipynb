# %% [markdown]
# # Recipes

# %%
from hubcap import git_clone, git_wiki_clone
from dol import TextFiles, filt_iter, Pipe

repo_py_files = Pipe(
    git_clone, TextFiles, filt_iter(filt=lambda x: x.endswith('.py'))
)
repo_wiki_files = Pipe(git_wiki_clone, TextFiles)

# %%
py_files = repo_py_files('i2mint/dol')
len(py_files)
# Out:
# Cloning into '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/tmp01o3lutw'...
# 37

# %%
wiki_files = repo_wiki_files('i2mint/dol')
list(wiki_files)
# Out:
# Cloning into '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/tmprr4aak1w'...
# ['Recipes.md',
#  'Critiques-and-their-comebacks.md',
#  'Home.md',
#  'Mapping-Views.md']

# %% [markdown]
# # Talking to github

# %% [markdown]
# The first few here don't require the github python package. Just `requests`.
#
# But they do require a token (e.g. in environment variable `GITHUB_TOKEN`).

# %%
import pandas as pd  # pip install pandas

# %% [markdown]
# ## Get repositories list

# %%
from hubcap.examples import repos_info, actions_info, date_selection_lidx
otosense = repos_info('otosense')
i2mint = repos_info('i2mint')

# %% [markdown]
# # RepoReader

# %%
from hubcap import RepoReader

s = RepoReader('thorwhalen/hubcap')
len(s)
# Out:
# 48

# %%
# the keys of a RepoReader object are the names of the different 
# things you can get from the repo
from lkj import wrapped_print

repo_reader_keys = list(s)
wrapped_print(repo_reader_keys)
# Out:
# artifacts, assignees, autolinks, branches, codescan_alerts, collaborators,
# comments, commits, contributors, dependabot_alerts, deployments, discussions,
# downloads, environments, events, forks, git_refs, hooks, issues,
# issues_comments, issues_events, labels, languages, milestones, network_events,
# notifications, pending_invitations, projects, pulls, pulls_comments,
# pulls_review_comments, releases, repository_advisories, secrets,
# self_hosted_runners, stargazers, stargazers_with_dates, stats_contributors,
# subscribers, tags, teams, top_paths, top_referrers, topics, variables, watchers,
# workflow_runs, workflows

# %% [markdown]
# ## Files (branches)

# %%
branches = s['branches']

# %%
list(branches)
# Out:
# ['master']

# %%
branch = branches['master']
branch
# Out:
# Branch(name="master")

# %% [markdown]
# ## Issues

# %%
issues = s['issues']
list(issues)
# Out:
# [3]

# %%
issue = issues[3]
list(issue)
# Out:
# ['body', 'comments']

# %%
issue['body']
# Out:
# 'This is just a test issue to test that hubcap can see it.\r\n'

# %%
comments = issue['comments']
list(comments)
# Out:
# [0, 1]

# %%
comments[0]
# Out:
# 'This is an issue comment.'

# %% [markdown]
# ## discussions

# %%
discussions = s['discussions']
list(discussions)
# Out:
# [2]

# %%
discussion = discussions[2]
discussion
# Out:
# {'number': 2,
#  'title': 'Root interface of hubcap',
#  'body': 'Every time I need to do something with `hubcap` I need to look up how it works again. \r\n\r\nThat\'s negative points for UX design right there! We should strive for "no manual needed". \r\n\r\nI made the mistake, yet again, of letting what I was wrapping have to much influence on the design of my interface. \r\nIt\'s okay, and even often desirable, to have a layer that is "inner oriented" (what I sometimes call the "long language"), \r\nbut we shouldn\'t forget the domain-oriented interface in the process. \r\n\r\nSo what would I want the interface to be?\r\n\r\n## Root\r\n\r\nI\'m considering something like, by default getting a mapping at the highest level of github (I\'ll use `Hubcap` here, since `GithubReader` is already used in my code):\r\n\r\n```python\r\ns = Hubcap()\r\nu = s[\'thorwhalen\']  # mapping of repos of thorwhalen\r\nlist(org)  # will list repos of thorwhalen user/org, for example\r\nr = u[\'hubcap\']  # mapping for the contents of the repo\r\n# etc.\r\n```\r\n\r\nRight now, we can do:\r\n\r\n```python\r\nss = GithubReader()\r\n```\r\n\r\nBut it will default to the user/org associated with the default login/token (the one used by the API). \r\n\r\nHere, `list(ss)` will list the repos for that user (we haven\'t defined what `list(s)` would be yet), but what\'s not nice is that you can\'t start at the very top of github. Is that a problem? Should we consider that the user must start with specifying a user/org first? Maybe. \r\n\r\nIf `Hubcap` has any iter, what would it be? Obviously, we wouldn\'t want to list all user/orgs. We could implement `__contains__` at that level, but listing all user/orgs (in list(s)) would result in a very long process. Perhaps we still default to the current user (as with GithubReader), or allow the user to specify a list of users/orgs to start with, or perhaps we list any org they\'re part of and/or starred... \r\n\r\n## And then...\r\n\r\nThe first level is user/org. Then there\'s repos (but are there other choices). What next?\r\n\r\nRight now we have `branch` as being the next level -- but again, what are the other choices?\r\nThere are other resources associated with the user/org. Issues, discussions, wikis, etc.\r\nFurther, even having to specify branches is annoying -- we\'d like to easily default to a branch and directly get to the files. \r\n\r\nSo the situation is that we have a tree -- something like (we\'ll just say "org" instead of "user/org" from now on. \r\n\r\n```\r\nROOT\r\n  ORGS\r\n    REPOS\r\n       ACTIONS\r\n       ISSUES\r\n          COMMENTS\r\n             REPLIES\r\n       DISCUSSIONS\r\n          COMMENTS\r\n             REPLIES\r\n       WIKIS\r\n       ...\r\n       BRANCHES\r\n          COMMITS\r\n             FILES\r\n```\r\n\r\nWe\'d like to have access to all these resources, with a mapping interface of the tree.\r\n\r\nWe\'d also like to have convenient mappings like `ORGS/REPOS/master/last_commit/FILES`. \r\n(Notice here that `master` is static, but `last_commit` is dynamic (it will change with time).)\r\n\r\nThis is not a `hubcap` problem by the way, but a general `dol` one. See for example, the `py2store` [Hypercubic keys and slicing](https://github.com/i2mint/py2store/issues/33) issue and [this comment](https://github.com/i2mint/py2store/issues/33#issuecomment-1798158170) mentioning the hubcap use case.\r\n\r\n',
#  'author': {'login': 'thorwhalen'},
#  'createdAt': '2023-11-07T09:30:59Z',
#  'updatedAt': '2023-12-05T08:25:39Z',
#  'comments': [{'body': 'Further it would be nice if we could access resources via a url copied as is from viewing it on the browser. \r\n\r\nIt\'s what the [hubcap.hub](https://github.com/thorwhalen/hubcap/blob/6d5d7b9813e068ef4bcf1e6b905cc2febd38e468/hubcap/tools.py#L18) function is intended to do -- and does, **at the time of writing this**, somewhat, partially, but with a terrible design and unreliable robustness (due to the fact that [RepoReader](https://github.com/thorwhalen/hubcap/blob/6d5d7b9813e068ef4bcf1e6b905cc2febd38e468/hubcap/base.py#L121) isn\'t really finished. What is left to do there is finish completing the declarative configuration that is [dflt_repo_kwargs](https://github.com/thorwhalen/hubcap/blob/6d5d7b9813e068ef4bcf1e6b905cc2febd38e468/hubcap/base.py#L102) and make things recursive (e.g. when we do `issue = repo_reader[\'issues\'][3]`, `issue` should be a `Mapping` with it\'s own key-value definition, which includes "leaf" properties (like title, creation date, etc.) as well as other nested mappings (such as comments). \r\n\r\n\r\n## Examples of github urls\r\n\r\n```\r\nhttps://github.com/thorwhalen/test_repo/tree/main/folder_1\r\n```\r\n\r\ncorresponds to \r\n\r\n```\r\n{"org": "thorwhalen", "repo": "test_repo", "branch": "main", "commit": "most_recent", "path": "folder_1/"}\r\n```\r\n\r\nwhose reduced form url could be\r\n\r\n```\r\nthorwhalen/test_repo/main/most_recent/folder_1\r\n```\r\n\r\nor even (with a default interpretation that assumes commit=most_recent without confusing commit and path):\r\n\r\n```\r\nthorwhalen/test_repo/main/folder_1\r\n```\r\n\r\nNote a few other urls (interpretation and pattern extraction left to the reader!):\r\n\r\n```\r\nhttps://github.com/thorwhalen/test_repo/blob/main/folder_1/file_1_level_2 \r\nhttps://github.com/thorwhalen/test_repo/blob/117dded5171a23d465f7b3d6ae3204a4e105cfb2/folder_1/file_1_level_2 \r\n```\r\n\r\nNote how the branch doesn\'t show when the commit hash is present. There must be a ledger that links a commit to the branch it was created on. I should read about the exact logic there! What does it mean as far a our dimensioned indexation schema goes? It seems we still need both a branch and a commit dimension since it\'s a many-to-1 relationship: a branch may have several commits.\r\n\r\nNote also how we had "tree" when the path pointed to a folder, replaced by "blob" when it points to a file (so, unlike in unix, where ["everything is a file"](https://en.wikipedia.org/wiki/Everything_is_a_file), a folder is not considered a file here?)\r\n\r\nMore...\r\n\r\n```\r\nhttps://github.com/thorwhalen/test_repo/wiki\r\nhttps://github.com/thorwhalen/test_repo/wiki/Test-Wiki-A\r\n\r\nhttps://github.com/thorwhalen/test_repo/issues\r\nhttps://github.com/thorwhalen/test_repo/issues/4\r\nhttps://github.com/thorwhalen/test_repo/issues/4#issuecomment-1801792378\r\n\r\nhttps://github.com/thorwhalen/test_repo/discussions\r\nhttps://github.com/thorwhalen/test_repo/discussions/1\r\nhttps://github.com/thorwhalen/test_repo/discussions/1#discussioncomment-7509953\r\nhttps://github.com/thorwhalen/test_repo/discussions/1#discussioncomment-7509957  # it\'s actually a comment "reply" here\r\n```\r\n\r\n\r\n\r\n\r\n',
#    'author': 'thorwhalen',
#    'replies': []}]}

# %%
discussion['title'], discussion['body'], [x['body'] for x in discussion['comments']]

# %%
from hubcap import hub, ensure_github_url

t = hub('thorwhalen/hubcap/discussions')

# %%
from hubcap.repo_slurp import discussions_mapping

discussions = discussions_mapping('thorwhalen/hubcap')

# %%
# print(next(iter(discussions.values())))

# %% [markdown]
# # Repository to text

# %% [markdown]
# In this day-and-age of AI, it can be useful to be able to create a text file containing all the info you want to capture from a github repository, so as to be able to feed to an AI for context.
#
# The following will (by default) slurp files, wikis and discussions and aggregate these in a markdown string (that you can then save somewhere yourself).

# %%
from hubcap import repo_text_aggregate

markdown_text = repo_text_aggregate('thorwhalen/hubcap')
# Out:
# Cloning into '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/tmpbaz121ea'...

# %%
from hubcap import repo_text_aggregate
from pathlib import Path

pkg = 'dol'
markdown_text = repo_text_aggregate(f'i2mint/{pkg}')
Path(f'~/Downloads/{pkg}.md').expanduser().write_text(markdown_text)
# Out:
# Cloning into '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/tmp1n66_iss'...
# Cloning into '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/tmpx488o7fw'...

# %%
from hubcap import repo_text_aggregate
from pathlib import Path

pkg = 'py2store'
markdown_text = repo_text_aggregate(f'i2mint/{pkg}')
Path(f'~/Downloads/{pkg}.md').expanduser().write_text(markdown_text)
# Out:
# Cloning into '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/tmp_7x33k_x'...
# Cloning into '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/tmppfg0zcp5'...
# 398659

# %% [markdown]
# # notebook to markdown

# %% [markdown]
# The default of repo_test_aggregate will only filter in .py and .md files.
#
# If you want to get some of your notebooks too, one trick would be to convert them to .md files.

# %%
from hubcap.repo_slurp import notebook_to_markdown
f = '/Users/thorwhalen/Dropbox/py/proj/notebooks/000 - misc.ipynb'
markdown_text_of_notebook = notebook_to_markdown(f)  #

# %% [markdown]
# ## Other keys of RepoReader

# %%
stargazers = RepoReader('i2mint/dol')['stargazers']
stargazers  # but you can't really do anything   # TODO: Make it work

# %%
# list(stargarzers)  # this will raise an error  # TODO: Should not.
# but this will work
list(stargazers.repo.get_stargazers())
# Out:
# [NamedUser(login="thejeshgn"),
#  NamedUser(login="cavart28"),
#  NamedUser(login="charlie-dufort"),
#  NamedUser(login="thorwhalen")]

# %% [markdown]
# # Cached stores

# %%
import hubcap 

artifacts = hubcap.local_repo_artifacts  # use hubcap.remote_repo_artifacts if you want fresh copies from remote

# %%
# sort repositories by number of issues (descending)
issues_repo_sorted_by_n_issues = sorted(artifacts.issues, key=lambda k: len(artifacts.issues[k]), reverse=True)
issues_repo_sorted_by_n_issues[:10]
# Out:
# ['i2mint/py2store',
#  'thorwhalen/umpyre',
#  'i2mint/i2i_scrap',
#  'i2mint/i2',
#  'i2mint/meshed',
#  'i2mint/front',
#  'i2mint/stream2py',
#  'i2mint/dol',
#  'i2mint/isee',
#  'i2mint/oui']

# %% [markdown]
# The values of discussions and issues are dicts with keys being issue numbers (integers), and values being the parsed content as dicts.

# %%
list(artifacts.discussions['thorwhalen/hubcap'])
# Out:
# [2, 4]

# %%
list(artifacts.issues['thorwhalen/hubcap'])
# Out:
# [3]

# %%
# get your discussions as dicts
discussion_jdict = artifacts.discussions['thorwhalen/hubcap'][4]
assert isinstance(discussion_jdict, dict)
# transform to markdown string
discussion_string = hubcap.create_markdown_from_jdict(discussion_jdict)
assert isinstance(discussion_string, str)

# same with issues: get them as dicts
issue_jdict = artifacts.issues['thorwhalen/hubcap'][3]
assert isinstance(issue_jdict, dict)
# ... and transform to markdown string
issue_string = hubcap.create_markdown_from_jdict(issue_jdict)
assert isinstance(issue_string, str)

# %%
print(discussion_string[:30], '...')
# Out:
# # Dev notes for `hubcap`
#
# Dev  ...

# %% [markdown]
# If you want direct access to an aggregate of all discussions or issues, just use `discussions_mds` and `issues_mds`.

# %%
artifacts.discussions_mds['thorwhalen/hubcap']
# Out:
# '# Root interface of hubcap (#2)\n\nEvery time I need to do something with `hubcap` I need to look up how it works again. \r\n\r\nThat\'s negative points for UX design right there! We should strive for "no manual needed". \r\n\r\nI made the mistake, yet again, of letting what I was wrapping have to much influence on the design of my interface. \r\nIt\'s okay, and even often desirable, to have a layer that is "inner oriented" (what I sometimes call the "long language"), \r\nbut we shouldn\'t forget the domain-oriented interface in the process. \r\n\r\nSo what would I want the interface to be?\r\n\r\n## Root\r\n\r\nI\'m considering something like, by default getting a mapping at the highest level of github (I\'ll use `Hubcap` here, since `GithubReader` is already used in my code):\r\n\r\n```python\r\ns = Hubcap()\r\nu = s[\'thorwhalen\']  # mapping of repos of thorwhalen\r\nlist(org)  # will list repos of thorwhalen user/org, for example\r\nr = u[\'hubcap\']  # mapping for the contents of the repo\r\n# etc.\r\n```\r\n\r\nRight now, we can do:\r\n\r\n```python\r\nss = GithubReader()\r\n```\r\n\r\nBut it will default to the user/org associated with the default login/token (the one used by the API). \r\n\r\nHere, `list(ss)` will list the repos for that user (we haven\'t defined what `list(s)` would be yet), but what\'s not nice is that you can\'t start at the very top of github. Is that a problem? Should we consider that the user must start with specifying a user/org first? Maybe. \r\n\r\nIf `Hubcap` has any iter, what would it be? Obviously, we wouldn\'t want to list all user/orgs. We could implement `__contains__` at that level, but listing all user/orgs (in list(s)) would result in a very long process. Perhaps we still default to the current user (as with GithubReader), or allow the user to specify a list of users/orgs to start with, or perhaps we list any org they\'re part of and/or starred... \r\n\r\n## And then...\r\n\r\nThe first level is user/org. Then there\'s repos (but are there other choices). What next?\r\n\r\nRight now we have `branch` as being the next level -- but again, what are the other choices?\r\nThere are other resources associated with the user/org. Issues, discussions, wikis, etc.\r\nFurther, even having to specify branches is annoying -- we\'d like to easily default to a branch and directly get to the files. \r\n\r\nSo the situation is that we have a tree -- something like (we\'ll just say "org" instead of "user/org" from now on. \r\n\r\n```\r\nROOT\r\n  ORGS\r\n    REPOS\r\n       ACTIONS\r\n       ISSUES\r\n          COMMENTS\r\n             REPLIES\r\n       DISCUSSIONS\r\n          COMMENTS\r\n             REPLIES\r\n       WIKIS\r\n       ...\r\n       BRANCHES\r\n          COMMITS\r\n             FILES\r\n```\r\n\r\nWe\'d like to have access to all these resources, with a mapping interface of the tree.\r\n\r\nWe\'d also like to have convenient mappings like `ORGS/REPOS/master/last_commit/FILES`. \r\n(Notice here that `master` is static, but `last_commit` is dynamic (it will change with time).)\r\n\r\nThis is not a `hubcap` problem by the way, but a general `dol` one. See for example, the `py2store` [Hypercubic keys and slicing](https://github.com/i2mint/py2store/issues/33) issue and [this comment](https://github.com/i2mint/py2store/issues/33#issuecomment-1798158170) mentioning the hubcap use case.\r\n\r\n\n\n## Comment\n\nFurther it would be nice if we could access resources via a url copied as is from viewing it on the browser. \r\n\r\nIt\'s what the [hubcap.hub](https://github.com/thorwhalen/hubcap/blob/6d5d7b9813e068ef4bcf1e6b905cc2febd38e468/hubcap/tools.py#L18) function is intended to do -- and does, **at the time of writing this**, somewhat, partially, but with a terrible design and unreliable robustness (due to the fact that [RepoReader](https://github.com/thorwhalen/hubcap/blob/6d5d7b9813e068ef4bcf1e6b905cc2febd38e468/hubcap/base.py#L121) isn\'t really finished. What is left to do there is fin ...

# %%
artifacts.issues_mds['thorwhalen/hubcap']
# Out:
# '# Test Issue (#3)\n\nThis is just a test issue to test that hubcap can see it.\r\n\n\n'

# %%
from pyperclip import copy

copy(artifacts.issues_mds['i2mint/stream2py'])

# %% [markdown]
# ## Refresh all cached

# %%
from hubcap import LocalRepoArtifacts

artifacts = LocalRepoArtifacts(refresh=True)
list(artifacts.discussions)
# Out:
# ['thorwhalen/hubcap']

# %%
for repo in artifacts.info:
    try:
        artifact = artifacts.discussions[repo]
    except Exception as e:
        print(f"Error retrieving discussions for {repo}: {e}")
    try:
        artifact = artifacts.issues[repo]
    except Exception as e:
        print(f"Error retrieving issues for {repo}: {e}")
# Out:
# Error retrieving discussions for thorwhalen/pj: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/repos/repos#get-a-repository", "status": "404"}
# Error retrieving issues for thorwhalen/pj: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/repos/repos#get-a-repository", "status": "404"}

# %%
from hubcap import local_repo_artifacts

# This lists repos that have cached info
cached_repos = list(local_repo_artifacts.info)
print(cached_repos)
# Out:
# ['thorwhalen/uu', 'thorwhalen/plunk', 'thorwhalen/librosa', 'thorwhalen/guide', 'thorwhalen/yp', 'thorwhalen/nbdol', 'thorwhalen/pj', 'thorwhalen/bumph', 'thorwhalen/get-the-default-branch-action', 'thorwhalen/essays', 'thorwhalen/thorwhalen', 'thorwhalen/ug', 'thorwhalen/template-scala-parallel-classification', 'thorwhalen/ut', 'thorwhalen/practice_deploying_webapps', 'thorwhalen/wealth', 'thorwhalen/mixing', 'thorwhalen/dn', 'thorwhalen/learny', 'thorwhalen/chroma', 'thorwhalen/allude', 'thorwhalen/datamodel-code-generator', 'thorwhalen/my_notebooks', 'thorwhalen/owner', 'thorwhalen/relativity', 'thorwhalen/skill', 'thorwhalen/hm', 'thorwhalen/tonal', 'thorwhalen/_cosmodata_dev_utils', 'thorwhalen/aw', 'thorwhalen/streamlit_apps', 'thorwhalen/hfdol', 'thorwhalen/imbed_data_prep', 'thorwhalen/equate', 'thorwhalen/pyparsing', 'thorwhalen/bc', 'thorwhalen/pynch', 'thorwhalen/linkedin-skill-assessments-quizzes', 'thorwhalen/astronify', 'thorwhalen/scoopy', 'thorwhalen/newut', 'thorwhalen/sonification', 'thorwhalen/predictive_maintenance', 'thorwhalen/esimport', 'thorwhalen/agen', 'thorwhalen/brand', 'thorwhalen/garble', 'thorwhalen/tapyoca', 'thorwhalen/test_repo', 'thorwhalen/wip_qh', 'thorwhalen/mood_files', 'thorwhalen/pystol', 'thorwhalen/sc_filter_interp', 'thorwhalen/analysis_dashboard', 'thorwhalen/content', 'thorwhalen/swipe', 'thorwhalen/pak', 'thorwhalen/cachetools', 'thorwhalen/hired', 'thorwhalen/wrapt', 'thorwhalen/hyp', 'thorwhalen/theremin', 'thorwhalen/scraped', 'thorwhalen/newsmood', 'thorwhalen/hedger', 'thorwhalen/py2api', 'thorwhalen/kroki', 'thorwhalen/astate', 'thorwhalen/oldpy2store', 'thorwhalen/contaix', 'thorwhalen/vin', 'thorwhalen/coact', 'thorwhalen/odus', 'thorwhalen/ps', 'thorwhalen/chatgpt-retrieval-plugin', 'thorwhalen/drug_lifecourse', 'thorwhalen/su', 'thorwhalen/manual', 'thorwhalen/voxy', 'thorwhalen/notes', 'thorwhalen/tcw', 'thorwhalen/my_sources', 'thorwhalen/hubcap', 'thorwhalen/ayn', 'thorwhalen/owned', 'thorwhalen/likert', 'thorwhalen/TimeCanvas', 'thorwhalen/nioc', 'thorwhalen/grub', 'thorwhalen/idiom', 'thorwhalen/spyn', 'thorwhalen/saying', 'thorwhalen/cult', 'thorwhalen/aw_agents', 'thorwhalen/guise', 'thorwhalen/chroma-core-docs', 'thorwhalen/py2request', 'thorwhalen/codify', 'thorwhalen/hg', 'thorwhalen/pipoke', 'thorwhalen/py2dash', 'thorwhalen/mv', 'thorwhalen/ef', 'thorwhalen/imbed', 'thorwhalen/lag', 'thorwhalen/oa', 'thorwhalen/sung', 'thorwhalen/lexis', 'thorwhalen/hire', 'thorwhalen/umpyre', 'thorwhalen/i2i', 'thorwhalen/stogui', 'thorwhalen/moji', 'thorwhalen/nlp_data', 'thorwhalen/ideas', 'thorwhalen/haggle', 'thorwhalen/funds', 'thorwhalen/sheet', 'thorwhalen/babe', 'thorwhalen/mood', 'thorwhalen/graze', 'thorwhalen/argh', 'thorwhalen/viral', 'thorwhalen/xv', 'thorwhalen/fbconsole', 'thorwhalen/msword', 'thorwhalen/vax', 'thorwhalen/loopyng', 'thorwhalen/sung_content', 'thorwhalen/elections', 'thorwhalen/aix', 'thorwhalen/invest', 'thorwhalen/hum', 'thorwhalen/laugh', 'i2mint/dexis', 'i2mint/flaskstream2py', 'i2mint/sqldol', 'i2mint/hear', 'i2mint/titbit', 'i2mint/peruse', 'i2mint/py2misc', 'i2mint/sshdol', 'i2mint/chromadol', 'i2mint/meshed', 'i2mint/config2py', 'i2mint/dagapp', 'i2mint/s3dol', 'i2mint/opyratorfront', 'i2mint/streamlitfront', 'i2mint/ftpdol', 'i2mint/slink', 'i2mint/odat', 'i2mint/oui', 'i2mint/git2py', 'i2mint/kafkaposted', 'i2mint/arangodol', 'i2mint/i2i_scrap', 'i2mint/larder', 'i2mint/audiostream2py', 'i2mint/tested', 'i2mint/pchealthstream2py', 'i2mint/shaded', 'i2mint/lkj', 'i2mint/embody', 'i2mint/oplot', 'i2mint/stream2py', 'i2mint/py2store', 'i2mint/dashfront', 'i2mint/ju', 'i2mint/focal', 'i2mint/dropboxdol', 'i2mint/forged', 'i2mint/test2doc', 'i2mint/pyckup', 'i2mint/fitted', 'i2mint/redisdol', 'i2mint/public_discussions', 'i2mint/redisposted', 'i2mint/qo', 'i2mint/content', 'i2mint/qh', 'i2mint/pydrivedol', 'i2mint/wads', 'i2mint/recode', 'i2mint/ooq', 'i2mint/py2c', 'i2mint/viable', 'i2mint/posted', 'i2mint/lined', 'i2mint/rh', 'i2mint/lin ...

# %%
local_repo_artifacts.discussions['thorwhalen/hubcap']
# Out:
# {4: {'number': 4,
#   'title': 'Dev notes for `hubcap`',
#   'body': 'Dev notes for `hubcap`',
#   'author': {'login': 'thorwhalen'},
#   'createdAt': '2025-10-30T18:04:28Z',
#   'updatedAt': '2025-10-30T18:06:25Z',
#   'comments': [{'body': '# Manual Authentication Upload (for 2FA users)\r\n\r\nIf you have 2FA enabled on GitHub, use this approach where you log in manually first, then the script takes over.\r\n\r\n## Usage in Jupyter\r\n\r\n```python\r\nfrom hubcap.scrap.social_preview import upload_social_preview_with_manual_auth_async\r\n\r\n# This will:\r\n# 1. Open a browser to GitHub login\r\n# 2. Wait for you to log in (including 2FA)\r\n# 3. Automatically navigate to settings and upload the image\r\n\r\nresult = await upload_social_preview_with_manual_auth_async(\r\n    repo_full_name=\'thorwhalen/graze\',\r\n    image_path=\'/Users/thorwhalen/Downloads/graze_image.png\',\r\n    headless=False  # Must be False so you can see to log in\r\n)\r\n```\r\n\r\n## What Happens:\r\n\r\n1. **Browser opens** - You\'ll see a browser window open to GitHub login\r\n2. **You log in** - Enter your username, password, and 2FA code manually\r\n3. **Script detects login** - Once you\'re logged in, the script automatically continues\r\n4. **Automatic upload** - Script navigates to settings and uploads your image\r\n5. **Confirmation** - You\'ll see success messages in your console\r\n\r\n## Full Example:\r\n\r\n```python\r\nimport os\r\nfrom hubcap.scrap.social_preview import upload_social_preview_with_manual_auth_async\r\n\r\n# Upload with manual login\r\nprint("Starting upload process...")\r\nprint("A browser will open - please log in to GitHub")\r\n\r\nresult = await upload_social_preview_with_manual_auth_async(\r\n    repo_full_name=\'thorwhalen/graze\',\r\n    image_path=\'/Users/thorwhalen/Downloads/graze_image.png\'\r\n)\r\n\r\nif result:\r\n    print("\\n✓ Successfully uploaded social preview!")\r\nelse:\r\n    print("\\n✗ Upload failed - check the error messages above")\r\n```\r\n\r\n## Tips:\r\n\r\n- **Don\'t close the browser** - Let the script control it after you log in\r\n- **Wait for automation** - After logging in, the script will automatically proceed\r\n- **Watch the console** - You\'ll see status messages as the script works\r\n- **Admin access required** - Make sure you have admin rights to the repo\r\n\r\n## Batch Upload Multiple Repos:\r\n\r\n```python\r\nrepos_and_images = [\r\n    (\'thorwhalen/graze\', \'/path/to/graze_image.png\'),\r\n    (\'thorwhalen/hubcap\', \'/path/to/hubcap_image.png\'),\r\n    (\'thorwhalen/dol\', \'/path/to/dol_image.png\'),\r\n]\r\n\r\n# Log in once, then upload to all repos\r\nprint("Please log in to GitHub in the browser that opens...")\r\n\r\nfor repo_name, image_path in repos_and_images:\r\n    print(f"\\n{\'=\'*60}")\r\n    print(f"Uploading to {repo_name}...")\r\n    print(f"{\'=\'*60}")\r\n    \r\n    result = await upload_social_preview_with_manual_auth_async(\r\n        repo_full_name=repo_name,\r\n        image_path=image_path\r\n    )\r\n    \r\n    if result:\r\n        print(f"✓ {repo_name} - Success")\r\n    else:\r\n        print(f"✗ {repo_name} - Failed")\r\n```\r\n\r\n## Troubleshooting:\r\n\r\n### "Could not find Edit button"\r\n- Make sure you have **admin access** to the repository\r\n- Try manually navigating to the settings page first to verify access\r\n\r\n### "Could not find Social Preview section"\r\n- The repo might not have the social preview feature enabled\r\n- Check if you can see it manually at `https://github.com/yourname/repo/settings`\r\n\r\n### Script times out during login\r\n- Default timeout is 3 minutes\r\n- Increase if needed: `timeout=300000` (5 minutes)\r\n\r\n### Browser closes too quickly\r\n- The browser stays open for 5 seconds after completion\r\n- You can manually keep it open longer if needed\r\n\r\n## Why This Approach Works:\r\n\r\n✓ **Handles 2FA** - You enter your 2FA code manually  \r\n✓ **Handles passkeys** - Works with any auth method GitHub supports  \r\n✓ **Session-based** - Uses your actual browser session  \r\n✓ **One login** - Can upload to multiple repos with one login  \r\n✓ **Visual feedback** - You can see exactly what\'s happening  \r\n ...
#     'author': 'thorwhalen',
#     'replies': []}]}}

# %% [markdown]
# # Checking on actions

# %% [markdown]
# # More stuff

# %% [markdown]
# ## See repository info for a whole organization
#
# (And caching the result)

# %%
from hubcap import GithubReader, get_repository_info

# %%
get_repository_info('thorwhalen/hubcap')
# Out:
# {'name': 'hubcap',
#  'full_name': 'thorwhalen/hubcap',
#  'description': 'A py2store (i.e. dict-like) interface to github',
#  'open_issues_count': 1,
#  'size': 5771,
#  'updated_at': datetime.datetime(2025, 10, 30, 21, 0, 43, tzinfo=datetime.timezone.utc),
#  'stargazers_count': 3,
#  'forks_count': 0,
#  'watchers_count': 3,
#  'html_url': 'https://github.com/thorwhalen/hubcap',
#  'last_commit_date': '2025-10-30'}

# %%
def org_repos_infos(org_name):
    org_repos = GithubReader(org_name)
    for repo_name in org_repos:
        full_name = f"{org_name}/{repo_name}"
        try:
            yield get_repository_info(full_name)
        except Exception as e:
            print(f"Error fetching info for {full_name}: {e}")
            print("Continuing...")

# %%
import pandas as pd

i2mint_repos_info = pd.DataFrame(org_repos_infos('i2mint', refresh=False))

# %%
i2mint_repos_info.sort_values('open_issues_count', ascending=False).iloc[18:40]
# Out:
#                   name                 full_name  \
# 54            mongodol           i2mint/mongodol
# 49               lined              i2mint/lined
# 66              peruse             i2mint/peruse
# 11               creek              i2mint/creek
# 98               taped              i2mint/taped
# 83              recode             i2mint/recode
# 107               verb               i2mint/verb
# 26             extrude            i2mint/extrude
# 84            redisdol           i2mint/redisdol
# 34                hear               i2mint/hear
# 88               s3dol              i2mint/s3dol
# 55                odat               i2mint/odat
# 46   keyboardstream2py  i2mint/keyboardstream2py
# 25            examples           i2mint/examples
# 105              unbox              i2mint/unbox
# 8            config2py          i2mint/config2py
# 29               focal              i2mint/focal
# 68              poclab             i2mint/poclab
# 4       audiostream2py     i2mint/audiostream2py
# 5             azuredol           i2mint/azuredol
# 6                 c2py               i2mint/c2py
# 15              dagapp             i2mint/dagapp
#
#                                            description  open_issues_count  \
# 54                           MongoDB Data Object Layer                  4
# 49                  Building simple pipelines, simply.                  4
# 66                       Explore a waveform with slang                  3
# 11                                      Simple streams                  3
# 98                     Python's serene access to audio                  3
# 83   Tools to make codecs for time-series serializa...                  3
# 107    Easily make mini-languages to do python things.                  2
# 26   Tool to run a composite web application to eas...                  2
# 84   redis with a simple (dict-like or list-like) i...                  2
# 34           Access audio data simply and consistently                  2
# 88   s3 (through boto3) with a simple (dict-like or...                  1
# 55   Tools to access raw and prepared sound/vibrati...                  1
# 46             stream2py interface for keyboard inputs                  1
# 25                        Examples of i2i applications                  1
# 105                            Finding imports in code                  1
# 8    Simplified reading and writing configurations ...                  1
# 29           Data Abstraction Objects for local files                   1
# 68                             Some explorations in AI                  1
# 4                        stream2py interface for audio                  1
# 5                      Azure Storage Data Object Layer                  1
# 6    Create python wrappers that call c functions, ...                  1
# 15   Making apps from DAGs by just snapping your fi...                  1
#
#       size                updated_at  stargazers_count  forks_count  \
# 54    6066 2025-08-26 11:24:27+00:00                 2            0
# 49    3179 2025-06-16 09:50:21+00:00                 2            0
# 66      59 2025-06-16 09:50:00+00:00                 1            0
# 11    3689 2025-08-21 16:17:44+00:00                 2            0
# 98    5719 2025-10-29 15:58:51+00:00                 0            0
# 83    5943 2025-04-23 13:08:15+00:00                 1            0
# 107    217 2025-08-26 11:24:02+00:00                 2            0
# 26    2938 2025-08-26 11:23:47+00:00                 2            0
# 84      35 2025-08-26 11:23:06+00:00                 0            0
# 34     249 2025-06-16 09:49:59+00:00                 1            0
# 88    5635 2025-10-16 20:37:06+00:00                 0            0
# 55      68 2025-06-16 09:50:05+00:00                 3            0
# 46    2914 2025-08-26 11:25:02+00:00                 0            0
# 25   19545 2025-08-22 20:11:58+00:00                 0            1
# 105    290 2025-10-15 21:30:07+00:00                 2            0
# 8     6400 2025-11-06 18:10:32+00:00                 0            0
# 29    5738 2025-01-06 18:31:26+00:00                 1            0
# 68    5324 2025-08-13 14:13:42+00:00                 0            0
# 4     3102 2025-08-21 16:21:00+00:00                 1            0
# 5     7016 2025-08-26 11:24:28+00:00                 0            0
# 6      155 2022-12-22 22:06:39+00:00                 0            0
# 15     468 2025-08-28 15:06:38+00:00                 5            0
#
#      watchers_count                                     html_url  \
# 54                2           https://github.com/i2mint/mongodol
# 49                2              https://github.com/i2mint/lined
# 66                1             https://github.com/i2mint/peruse
# 11                2              https://github.com/i2mint/creek
# 98                0              https://github.com/i2mint/taped
# 83                1             https://github.com/i2mint/recode
# 107               2               https://github.com/i2mint/verb
# 26                2            https://github.com/i2mint/extrude
# 84                0           https://github.com/i2mint/redisdol
# 34                1               https://github.com/i2mint/hear
# 88                0              https://github.com/i2mint/s3dol
# 55                3               https://github.com/i2mint/odat
# 46                0  https://github.com/i2mint/keyboardstream2py
# 25                0           https://github.com/i2mint/examples
# 105               2              https://github.com/i2mint/unbox
# 8                 0          https://github.com/i2mint/config2py
# 29                1              https://github.com/i2mint/focal
# 68                0             https://github.com/i2mint/poclab
# 4                 1     https://github.com/i2mint/audiostream2py
# 5                 0           https://github.com/i2mint/azuredol
# 6                 0               https://github.com/i2mint/c2py
# 15                5             https://github.com/i2mint/dagapp
#
#     last_commit_date
# 54        2025-08-26
# 49        2025-06-16
# 66        2025-06-16
# 11        2025-08-21
# 98        2025-10-29
# 83        2025-04-23
# 107       2025-08-26
# 26        2025-08-26
# 84        2025-08-26
# 34        2025-06-16
# 88        2025-10-16
# 55        2025-06-16
# 46        2025-08-26
# 25        2025-08-22
# 105       2025-10-15
# 8         2025-11-06
# 29        2025-01-06
# 68        2025-08-13
# 4         2025-08-21
# 5         2025-08-26
# 6         2022-12-22
# 15        2025-08-28

# %%
# This one took 16mn to refresh!!!
tw_repos_info =pd.DataFrame(org_repos_infos('thorwhalen', refresh=False))
# Out:
# Error fetching info for thorwhalen/boltons: Cannot complete object as it contains no URL: 400
# Continuing...
# Error fetching info for thorwhalen/cpython: Cannot complete object as it contains no URL: 400
# Continuing...
# Error fetching info for thorwhalen/hydejack-site: Cannot complete object as it contains no URL: 400
# Continuing...
# Error fetching info for thorwhalen/pandas: Cannot complete object as it contains no URL: 400
# Continuing...
# Error fetching info for thorwhalen/python-progressbar: Cannot complete object as it contains no URL: 400
# Continuing...

# %%
tw_repos_info.sort_values('open_issues_count', ascending=False).iloc[5:20]
# Out:
#            name              full_name  \
# 35        graze       thorwhalen/graze
# 80           oa          thorwhalen/oa
# 116   test_repo   thorwhalen/test_repo
# 92       py2api      thorwhalen/py2api
# 79        notes       thorwhalen/notes
# 2        allude      thorwhalen/allude
# 51        ideas       thorwhalen/ideas
# 56        kroki       thorwhalen/kroki
# 114         tcw         thorwhalen/tcw
# 33       garble      thorwhalen/garble
# 117    theremin    thorwhalen/theremin
# 118  thorwhalen  thorwhalen/thorwhalen
# 8     aw_agents   thorwhalen/aw_agents
# 86       pipoke      thorwhalen/pipoke
# 48          hum         thorwhalen/hum
#
#                                            description  open_issues_count  \
# 35               Caching (a tiny part of) the internet                  2
# 80                          Python interface to OpenAi                  2
# 116           A repository for testing repository CRUD                  2
# 92   Expose python objects to a rest web service wi...                  2
# 79                                          Misc notes                  1
# 2    Building precise functionality from vague spec...                  1
# 51   Just a place to jot down some ideas about proj...                  1
# 56                            Access kroki from python                  1
# 114                           Medley of small packages                  1
# 33   Make bags of words and do stuff with them for ...                  1
# 117                          A video-to-sound theramin                  1
# 118                                               None                  1
# 8                               Ready to use AI Agents                  1
# 86           Acquisition and analyses of pypi packages                  1
# 48                                                None                  1
#
#        size                updated_at  stargazers_count  forks_count  \
# 35     5963 2025-10-30 18:00:09+00:00                 2            0
# 80     7296 2025-11-07 17:32:05+00:00                 0            0
# 116       4 2023-11-07 15:49:19+00:00                 0            0
# 92      129 2025-08-22 20:08:59+00:00                 5            3
# 79        0 2022-01-19 13:15:08+00:00                 1            0
# 2       210 2025-09-07 17:23:23+00:00                 2            0
# 51       14 2023-05-09 08:27:17+00:00                 0            0
# 56     5415 2025-08-22 17:44:02+00:00                 1            3
# 114       6 2022-01-19 13:15:05+00:00                 1            0
# 33       13 2025-08-26 11:21:20+00:00                 1            0
# 117  214461 2025-11-04 23:10:08+00:00                 0            0
# 118     619 2022-01-19 13:15:15+00:00                 1            0
# 8        42 2025-11-06 17:35:23+00:00                 0            0
# 86     7435 2025-08-26 11:21:43+00:00                 1            0
# 48    38088 2025-08-13 14:15:21+00:00                 3            2
#
#      watchers_count                                  html_url last_commit_date
# 35                2       https://github.com/thorwhalen/graze       2025-10-30
# 80                0          https://github.com/thorwhalen/oa       2025-11-07
# 116               0   https://github.com/thorwhalen/test_repo       2023-11-07
# 92                5      https://github.com/thorwhalen/py2api       2025-08-22
# 79                1       https://github.com/thorwhalen/notes       2022-01-19
# 2                 2      https://github.com/thorwhalen/allude       2025-09-07
# 51                0       https://github.com/thorwhalen/ideas       2023-05-09
# 56                1       https://github.com/thorwhalen/kroki       2025-08-22
# 114               1         https://github.com/thorwhalen/tcw       2022-01-19
# 33                1      https://github.com/thorwhalen/garble       2025-08-26
# 117               0    https://github.com/thorwhalen/theremin       2025-11-04
# 118               1  https://github.com/thorwhalen/thorwhalen       2022-01-19
# 8                 0   https://github.com/thorwhalen/aw_agents       2025-11-06
# 86                1      https://github.com/thorwhalen/pipoke       2025-08-26
# 48                3         https://github.com/thorwhalen/hum       2025-08-13

# %% [markdown]
# ## See recently updated repos

# %%
repos = i2mint

# %%
from hubcap.examples import date_selection_lidx, get_last_build_status

updated_recently = repos.iloc[date_selection_lidx(repos, hours_ago=24 * 200)]
updated_recently
# Out:
#                               id                           node_id  \
# full_name
# i2mint/streamlitfront  447351185                      R_kgDOGqoJkQ
# i2mint/dagapp          390780136  MDEwOlJlcG9zaXRvcnkzOTA3ODAxMzY=
# i2mint/http2py         260470410  MDEwOlJlcG9zaXRvcnkyNjA0NzA0MTA=
# i2mint/i2              183055954  MDEwOlJlcG9zaXRvcnkxODMwNTU5NTQ=
# i2mint/mongodol        341721959  MDEwOlJlcG9zaXRvcnkzNDE3MjE5NTk=
# i2mint/extrude         452468322                      R_kgDOGvgeYg
# i2mint/dashfront       468029481                      R_kgDOG-WQKQ
# i2mint/front           375158396  MDEwOlJlcG9zaXRvcnkzNzUxNTgzOTY=
# i2mint/py2api          270720023  MDEwOlJlcG9zaXRvcnkyNzA3MjAwMjM=
# i2mint/dynamodol       356079065  MDEwOlJlcG9zaXRvcnkzNTYwNzkwNjU=
# i2mint/crude           455676004                      R_kgDOGykQZA
# i2mint/py2dash         188473500  MDEwOlJlcG9zaXRvcnkxODg0NzM1MDA=
# i2mint/examples        203018601  MDEwOlJlcG9zaXRvcnkyMDMwMTg2MDE=
#
#                                  name              full_name  private  \
# full_name
# i2mint/streamlitfront  streamlitfront  i2mint/streamlitfront    False
# i2mint/dagapp                  dagapp          i2mint/dagapp    False
# i2mint/http2py                http2py         i2mint/http2py    False
# i2mint/i2                          i2              i2mint/i2    False
# i2mint/mongodol              mongodol        i2mint/mongodol    False
# i2mint/extrude                extrude         i2mint/extrude    False
# i2mint/dashfront            dashfront       i2mint/dashfront    False
# i2mint/front                    front           i2mint/front    False
# i2mint/py2api                  py2api          i2mint/py2api    False
# i2mint/dynamodol            dynamodol       i2mint/dynamodol    False
# i2mint/crude                    crude           i2mint/crude    False
# i2mint/py2dash                py2dash         i2mint/py2dash    False
# i2mint/examples              examples        i2mint/examples    False
#
#                                                                    owner  \
# full_name
# i2mint/streamlitfront  {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/dagapp          {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/http2py         {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/i2              {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/mongodol        {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/extrude         {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/dashfront       {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/front           {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/py2api          {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/dynamodol       {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/crude           {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/py2dash         {'login': 'i2mint', 'id': 47563785, 'node_id':...
# i2mint/examples        {'login': 'i2mint', 'id': 47563785, 'node_id':...
#
#                                                        html_url  \
# full_name
# i2mint/streamlitfront  https://github.com/i2mint/streamlitfront
# i2mint/dagapp                  https://github.com/i2mint/dagapp
# i2mint/http2py                https://github.com/i2mint/http2py
# i2mint/i2                          https://github.com/i2mint/i2
# i2mint/mongodol              https://github.com/i2mint/mongodol
# i2mint/extrude                https://github.com/i2mint/extrude
# i2mint/dashfront            https://github.com/i2mint/dashfront
# i2mint/front                    https://github.com/i2mint/front
# i2mint/py2api                  https://github.com/i2mint/py2api
# i2mint/dynamodol            https://github.com/i2mint/dynamodol
# i2mint/crude                    https://github.com/i2mint/crude
# i2mint/py2dash                https://github.com/i2mint/py2dash
# i2mint/examples              https://github.com/i2mint/examples
#
#                                                              description  \
# full_name
# i2mint/streamlitfront  Generate streamlit frontends from python funct...
# i2mint/dagapp          Making apps from DAGs by just snapping your fi...
# i2mint/http2py         Tools to create python binders to http web ser...
# i2mint/i2                    Python Mint creation, manipulation, and use
# i2mint/mongodol                                MongoDB Data Object Layer
# i2mint/extrude         Tool to run a composite web application to eas...
# i2mint/dashfront                      dash plugin for the front UI maker
# i2mint/front            Getting from python objects to UIs exposing them
# i2mint/py2api          Expose python objects to a rest web service wi...
# i2mint/dynamodol       dynamodb (through boto3) with a simple (dict-l...
# i2mint/crude           Control complex python object through basic types
# i2mint/py2dash         Tools to produce dash (plot.ly) interfaces fro...
# i2mint/examples                             Examples of i2i applications
#
#                         fork  \
# full_name
# i2mint/streamlitfront  False
# i2mint/dagapp          False
# i2mint/http2py         False
# i2mint/i2              False
# i2mint/mongodol        False
# i2mint/extrude         False
# i2mint/dashfront       False
# i2mint/front           False
# i2mint/py2api           True
# i2mint/dynamodol       False
# i2mint/crude           False
# i2mint/py2dash         False
# i2mint/examples        False
#
#                                                                      url  ...  \
# full_name                                                                 ...
# i2mint/streamlitfront  https://api.github.com/repos/i2mint/streamlitf...  ...
# i2mint/dagapp                 https://api.github.com/repos/i2mint/dagapp  ...
# i2mint/http2py               https://api.github.com/repos/i2mint/http2py  ...
# i2mint/i2                         https://api.github.com/repos/i2mint/i2  ...
# i2mint/mongodol             https://api.github.com/repos/i2mint/mongodol  ...
# i2mint/extrude               https://api.github.com/repos/i2mint/extrude  ...
# i2mint/dashfront           https://api.github.com/repos/i2mint/dashfront  ...
# i2mint/front                   https://api.github.com/repos/i2mint/front  ...
# i2mint/py2api                 https://api.github.com/repos/i2mint/py2api  ...
# i2mint/dynamodol           https://api.github.com/repos/i2mint/dynamodol  ...
# i2mint/crude                   https://api.github.com/repos/i2mint/crude  ...
# i2mint/py2dash               https://api.github.com/repos/i2mint/py2dash  ...
# i2mint/examples             https://api.github.com/repos/i2mint/examples  ...
#
#                       allow_forking is_template web_commit_signoff_required  \
# full_name
# i2mint/streamlitfront          True       False                       False
# i2mint/dagapp                  True       False                       False
# i2mint/http2py                 True       False                       False
# i2mint/i2                      True       False                       False
# i2mint/mongodol                True       False                       False
# i2mint/extrude                 True       False                       False
# i2mint/dashfront               True       False                       False
# i2mint/front                   True       False                       False
# i2mint/py2api                  True       False                       False
# i2mint/dynamodol               True       False                       False
# i2mint/crude                   True       False                       False
# i2mint/py2dash                 True       False                       False
# i2mint/examples                True       False                       False
#
#                                                                   topics  \
# full_name
# i2mint/streamlitfront                                                 []
# i2mint/dagapp                                                         []
# i2mint/http2py         [api-wrapper, http, python, requests, webservice]
# i2mint/i2                                                             []
# i2mint/mongodol                                                       []
# i2mint/extrude                                                        []
# i2mint/dashfront                                                      []
# i2mint/front                                                          []
# i2mint/py2api                                                         []
# i2mint/dynamodol                                                      []
# i2mint/crude                                                          []
# i2mint/py2dash                                                        []
# i2mint/examples                                                       []
#
#                       visibility forks open_issues watchers default_branch  \
# full_name
# i2mint/streamlitfront     public     0           1        1         master
# i2mint/dagapp             public     0           1        2         master
# i2mint/http2py            public     1           3        2         master
# i2mint/i2                 public     1          18        1         master
# i2mint/mongodol           public     0           3        1         master
# i2mint/extrude            public     0           2        1         master
# i2mint/dashfront          public     0           0        0         master
# i2mint/front              public     1          16        2         master
# i2mint/py2api             public     0           0        0         master
# i2mint/dynamodol          public     0           0        0         master
# i2mint/crude              public     0           0        0         master
# i2mint/py2dash            public     1           4        2         master
# i2mint/examples           public     1           1        0         master
#
#                                                              permissions
# full_name
# i2mint/streamlitfront  {'admin': True, 'maintain': True, 'push': True...
# i2mint/dagapp          {'admin': True, 'maintain': True, 'push': True...
# i2mint/http2py         {'admin': True, 'maintain': True, 'push': True...
# i2mint/i2              {'admin': True, 'maintain': True, 'push': True...
# i2mint/mongodol        {'admin': True, 'maintain': True, 'push': True...
# i2mint/extrude         {'admin': True, 'maintain': True, 'push': True...
# i2mint/dashfront       {'admin': True, 'maintain': True, 'push': True...
# i2mint/front           {'admin': True, 'maintain': True, 'push': True...
# i2mint/py2api          {'admin': True, 'maintain': True, 'push': True...
# i2mint/dynamodol       {'admin': True, 'maintain': True, 'push': True...
# i2mint/crude           {'admin': True, 'maintain': True, 'push': True...
# i2mint/py2dash         {'admin': True, 'maintain': True, 'push': True...
# i2mint/examples        {'admin': True, 'maintain': True, 'push': True...
#
# [13 rows x 79 columns]

# %% [markdown]
# ## check if most recently changed repositories' CI failed or not

# %%
repos = i2mint
updated_recently = repos.iloc[date_selection_lidx(repos, hours_ago=24 * 365)]
i2mint_cis = {repo: get_last_build_status(repo) for repo in updated_recently['full_name']}
print(pd.Series(i2mint_cis))
# Out:
# i2mint/streamlitfront    success
# i2mint/dagapp            success
# i2mint/http2py           success
# i2mint/i2                success
# i2mint/mongodol          success
#                           ...
# i2mint/udos              failure
# i2mint/qh                   None
# i2mint/pyckup            failure
# i2mint/c2py                 None
# i2mint/dexis             failure
# Length: 61, dtype: object

# %%
repos = otosense
updated_recently = repos.iloc[date_selection_lidx(repos, hours_ago=24 * 365)]
otosense_cis = {repo: get_last_build_status(repo) for repo in updated_recently['full_name']}
print(pd.Series(otosense_cis))
# Out:
# otosense/know            failure
# otosense/plunk           failure
# otosense/shaded          success
# otosense/odat               None
# otosense/trait              None
# otosense/toy                None
# otosense/components         None
# otosense/qo                 None
# otosense/splatter           None
# otosense/oplot           success
# otosense/hum             success
# otosense/fitted          success
# otosense/content            None
# otosense/hear            failure
# otosense/recode          success
# otosense/oui                None
# otosense/lined           failure
# otosense/taped           success
# otosense/atypes          failure
# otosense/slang           failure
# otosense/viable          success
# otosense/gurgle          success
# otosense/forged          failure
# otosense/linkup          success
# otosense/slink           success
# otosense/omisc              None
# otosense/oui_notebook       None
# otosense/ooq                None
# otosense/peruse             None
# dtype: object

# %%
print(pd.Series(i2mint_cis))
# Out:
# otosense/know            failure
# otosense/plunk           failure
# otosense/shaded          success
# otosense/odat               None
# otosense/trait              None
# otosense/toy                None
# otosense/components         None
# otosense/qo                 None
# otosense/splatter           None
# otosense/oplot           success
# otosense/hum             success
# otosense/fitted          success
# otosense/content            None
# otosense/hear            failure
# otosense/recode          success
# otosense/oui                None
# otosense/lined           failure
# otosense/taped           success
# otosense/atypes          failure
# otosense/slang           failure
# otosense/viable          success
# otosense/gurgle          success
# otosense/forged          failure
# otosense/linkup          success
# otosense/slink           success
# otosense/omisc              None
# otosense/oui_notebook       None
# otosense/ooq                None
# otosense/peruse             None
# dtype: object

# %% [markdown]
# ## See actions status of repository

# %%
actions_info('otosense/recode')
# Out:
#            id                    name               node_id head_branch  \
# 0  1482617159  Continuous Integration  WFR_kwLOFotyws5YXvFH      master
# 1  1482609040  Continuous Integration  WFR_kwLOFotyws5YXtGQ      master
# 2  1451323898  Continuous Integration  WFR_kwLOFotyws5WgXH6      master
# 3  1451093355  Continuous Integration  WFR_kwLOFotyws5Wfe1r      master
# 4  1446073840  Continuous Integration  WFR_kwLOFotyws5WMVXw      master
# 5  1445890664  Continuous Integration  WFR_kwLOFotyws5WLopo      master
# 6  1334360205  Continuous Integration  WFR_kwLOFotyws5PiLiN      master
# 7  1207387860  Continuous Integration  WFR_kwLOFotyws5H90bU      master
# 8  1207387459  Continuous Integration  WFR_kwLOFotyws5H90VD      master
# 9  1207386641  Continuous Integration  WFR_kwLOFotyws5H90IR      master
#
#                                    head_sha  run_number event     status  \
# 0  c04fee2376fd99be48225b029c46cae48d7faa64          27  push  completed
# 1  99ab14d08b4265487b032d55c178564607f2a0b5          26  push  completed
# 2  e7412685be5d99b4421910ca4b08efefed8529fa          25  push  completed
# 3  73ac6ad5cd36b91a68c09212e5f3861a267ae9d8          24  push  completed
# 4  46c569b11db2da8ef1df48cb268d0ec29136c87b          23  push  completed
# 5  8a936e2a36f45128139f8c8419c2edb6bd6eb257          22  push  completed
# 6  8a0dd8c1ba3fc17883907c12e12ea4fa1fd39bc6          21  push  completed
# 7  9adaa01285efc20b1816f6afaebcd7512500c7f4          20  push  completed
# 8  502dd673aaceab85d760dd0f440311d89e9240cf          19  push  completed
# 9  c9e7cd2e0c435d66bbe0e90e03f90616e41db349          18  push  completed
#
#   conclusion  workflow_id  ...  \
# 0    success     10563228  ...
# 1    success     10563228  ...
# 2    success     10563228  ...
# 3    success     10563228  ...
# 4    success     10563228  ...
# 5    success     10563228  ...
# 6    success     10563228  ...
# 7    success     10563228  ...
# 8    failure     10563228  ...
# 9    failure     10563228  ...
#
#                                             logs_url  \
# 0  https://api.github.com/repos/otosense/recode/a...
# 1  https://api.github.com/repos/otosense/recode/a...
# 2  https://api.github.com/repos/otosense/recode/a...
# 3  https://api.github.com/repos/otosense/recode/a...
# 4  https://api.github.com/repos/otosense/recode/a...
# 5  https://api.github.com/repos/otosense/recode/a...
# 6  https://api.github.com/repos/otosense/recode/a...
# 7  https://api.github.com/repos/otosense/recode/a...
# 8  https://api.github.com/repos/otosense/recode/a...
# 9  https://api.github.com/repos/otosense/recode/a...
#
#                                      check_suite_url  \
# 0  https://api.github.com/repos/otosense/recode/c...
# 1  https://api.github.com/repos/otosense/recode/c...
# 2  https://api.github.com/repos/otosense/recode/c...
# 3  https://api.github.com/repos/otosense/recode/c...
# 4  https://api.github.com/repos/otosense/recode/c...
# 5  https://api.github.com/repos/otosense/recode/c...
# 6  https://api.github.com/repos/otosense/recode/c...
# 7  https://api.github.com/repos/otosense/recode/c...
# 8  https://api.github.com/repos/otosense/recode/c...
# 9  https://api.github.com/repos/otosense/recode/c...
#
#                                        artifacts_url  \
# 0  https://api.github.com/repos/otosense/recode/a...
# 1  https://api.github.com/repos/otosense/recode/a...
# 2  https://api.github.com/repos/otosense/recode/a...
# 3  https://api.github.com/repos/otosense/recode/a...
# 4  https://api.github.com/repos/otosense/recode/a...
# 5  https://api.github.com/repos/otosense/recode/a...
# 6  https://api.github.com/repos/otosense/recode/a...
# 7  https://api.github.com/repos/otosense/recode/a...
# 8  https://api.github.com/repos/otosense/recode/a...
# 9  https://api.github.com/repos/otosense/recode/a...
#
#                                           cancel_url  \
# 0  https://api.github.com/repos/otosense/recode/a...
# 1  https://api.github.com/repos/otosense/recode/a...
# 2  https://api.github.com/repos/otosense/recode/a...
# 3  https://api.github.com/repos/otosense/recode/a...
# 4  https://api.github.com/repos/otosense/recode/a...
# 5  https://api.github.com/repos/otosense/recode/a...
# 6  https://api.github.com/repos/otosense/recode/a...
# 7  https://api.github.com/repos/otosense/recode/a...
# 8  https://api.github.com/repos/otosense/recode/a...
# 9  https://api.github.com/repos/otosense/recode/a...
#
#                                            rerun_url previous_attempt_url  \
# 0  https://api.github.com/repos/otosense/recode/a...                 None
# 1  https://api.github.com/repos/otosense/recode/a...                 None
# 2  https://api.github.com/repos/otosense/recode/a...                 None
# 3  https://api.github.com/repos/otosense/recode/a...                 None
# 4  https://api.github.com/repos/otosense/recode/a...                 None
# 5  https://api.github.com/repos/otosense/recode/a...                 None
# 6  https://api.github.com/repos/otosense/recode/a...                 None
# 7  https://api.github.com/repos/otosense/recode/a...                 None
# 8  https://api.github.com/repos/otosense/recode/a...                 None
# 9  https://api.github.com/repos/otosense/recode/a...                 None
#
#                                         workflow_url  \
# 0  https://api.github.com/repos/otosense/recode/a...
# 1  https://api.github.com/repos/otosense/recode/a...
# 2  https://api.github.com/repos/otosense/recode/a...
# 3  https://api.github.com/repos/otosense/recode/a...
# 4  https://api.github.com/repos/otosense/recode/a...
# 5  https://api.github.com/repos/otosense/recode/a...
# 6  https://api.github.com/repos/otosense/recode/a...
# 7  https://api.github.com/repos/otosense/recode/a...
# 8  https://api.github.com/repos/otosense/recode/a...
# 9  https://api.github.com/repos/otosense/recode/a...
#
#                                          head_commit  \
# 0  {'id': 'c04fee2376fd99be48225b029c46cae48d7faa...
# 1  {'id': '99ab14d08b4265487b032d55c178564607f2a0...
# 2  {'id': 'e7412685be5d99b4421910ca4b08efefed8529...
# 3  {'id': '73ac6ad5cd36b91a68c09212e5f3861a267ae9...
# 4  {'id': '46c569b11db2da8ef1df48cb268d0ec29136c8...
# 5  {'id': '8a936e2a36f45128139f8c8419c2edb6bd6eb2...
# 6  {'id': '8a0dd8c1ba3fc17883907c12e12ea4fa1fd39b...
# 7  {'id': '9adaa01285efc20b1816f6afaebcd7512500c7...
# 8  {'id': '502dd673aaceab85d760dd0f440311d89e9240...
# 9  {'id': 'c9e7cd2e0c435d66bbe0e90e03f90616e41db3...
#
#                                           repository  \
# 0  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 1  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 2  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 3  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 4  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 5  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 6  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 7  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 8  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 9  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
#
#                                      head_repository
# 0  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 1  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 2  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 3  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 4  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 5  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 6  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 7  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 8  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
# 9  {'id': 378237634, 'node_id': 'MDEwOlJlcG9zaXRv...
#
# [10 rows x 30 columns]

# %% [markdown]
# # Appendix: workflow scrap

# %%
from hubcap import GitHubReader

s = GitHubReader('i2mint', login_or_token=os.environ['GITHUB_TOKEN'])
list(s)
# Out:
# ['aiofiledol',
#  'allude',
#  'arangodol',
#  'audiostream2py',
#  'c2py',
#  'config2py',
#  'couchdol',
#  'creek',
#  'dacc',
#  'dagapp',
#  'dexis',
#  'dol',
#  'dropboxdol',
#  'dynamodol',
#  'embody',
#  'epythet',
#  'examples',
#  'flaskstream2py',
#  'focal',
#  'front',
#  'ftpdol',
#  'git2py',
#  'http2js',
#  'http2py',
#  'i2',
#  'i2i_scrap',
#  'isee',
#  'keyboardstream2py',
#  'meshed',
#  'mongodol',
#  'odbcdol',
#  'on',
#  'pchealthstream2py',
#  'plcstream2py',
#  'py2api',
#  'py2dash',
#  'py2http',
#  'py2json',
#  'py2misc',
#  'py2mqtt',
#  'py2store',
#  'pyckup',
#  'pydrivedol',
#  'qh',
#  'redisdol',
#  's3dol',
#  'sqldol',
#  'sshdol',
#  'strand',
#  'stream2py',
#  'tabled',
#  'test2doc',
#  'tested',
#  'udos',
#  'umpyre',
#  'unbox',
#  'verb',
#  'videostream2py',
#  'wads',
#  'zu']

# %%
t = s['dol']
list(t)
# Out:
# ['master']

# %%
t['master']
# Out:
# BranchDir(Repository(full_name="i2mint/dol"), 'master', '', <function decoded_contents at 0x125bdaca0>)

# %%
dir(t.src)
# Out:
# ['CHECK_AFTER_INIT_FLAG',
#  '_CompletableGithubObject__complete',
#  '_CompletableGithubObject__completed',
#  '_GithubObject__makeSimpleAttribute',
#  '_GithubObject__makeSimpleListAttribute',
#  '_GithubObject__makeTransformedAttribute',
#  '_Repository__create_pull',
#  '_Repository__create_pull_1',
#  '_Repository__create_pull_2',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_allow_merge_commit',
#  '_allow_rebase_merge',
#  '_allow_squash_merge',
#  '_archive_url',
#  '_archived',
#  '_assignees_url',
#  '_blobs_url',
#  '_branches_url',
#  '_clone_url',
#  '_collaborators_url',
#  '_comments_url',
#  '_commits_url',
#  '_compare_url',
#  '_completeIfNeeded',
#  '_completeIfNotSet',
#  '_contents_url',
#  '_contributors_url',
#  '_created_at',
#  '_default_branch',
#  '_delete_branch_on_merge',
#  '_deployments_url',
#  '_description',
#  '_downloads_url',
#  '_events_url',
#  '_fork',
#  '_forks',
#  '_forks_count',
#  '_forks_url',
#  '_full_name',
#  '_git_commits_url',
#  '_git_refs_url',
#  '_git_tags_url',
#  '_git_url',
#  '_has_downloads',
#  '_has_issues',
#  '_has_pages',
#  '_has_projects',
#  '_has_wiki',
#  '_headers',
#  '_homepage',
#  '_hooks_url',
#  '_html_url',
#  '_hub',
#  '_id',
#  '_identity',
#  '_initAttributes',
#  '_issue_comment_url',
#  '_issue_events_url',
#  '_issues_url',
#  '_keys_url',
#  '_labels_url',
#  '_language',
#  '_languages_url',
#  '_legacy_convert_issue',
#  '_makeBoolAttribute',
#  '_makeClassAttribute',
#  '_makeDatetimeAttribute',
#  '_makeDictAttribute',
#  '_makeDictOfStringsToClassesAttribute',
#  '_makeFloatAttribute',
#  '_makeIntAttribute',
#  '_makeListOfClassesAttribute',
#  '_makeListOfDictsAttribute',
#  '_makeListOfIntsAttribute',
#  '_makeListOfListOfStringsAttribute',
#  '_makeListOfStringsAttribute',
#  '_makeStringAttribute',
#  '_makeTimestampAttribute',
#  '_master_branch',
#  '_merges_url',
#  '_milestones_url',
#  '_mirror_url',
#  '_name',
#  '_network_count',
#  '_notifications_url',
#  '_open_issues',
#  '_open_issues_count',
#  '_organization',
#  '_owner',
#  '_parent',
#  '_parentUrl',
#  '_permissions',
#  '_private',
#  '_pulls_url',
#  '_pushed_at',
#  '_rawData',
#  '_releases_url',
#  '_requester',
#  '_size',
#  '_source',
#  '_ssh_url',
#  '_stargazers_count',
#  '_stargazers_url',
#  '_statuses_url',
#  '_storeAndUseAttributes',
#  '_subscribers_count',
#  '_subscribers_url',
#  '_subscription_url',
#  '_svn_url',
#  '_tags_url',
#  '_teams_url',
#  '_trees_url',
#  '_updated_at',
#  '_url',
#  '_useAttributes',
#  '_watchers',
#  '_watchers_count',
#  'add_to_collaborators',
#  'allow_merge_commit',
#  'allow_rebase_merge',
#  'allow_squash_merge',
#  'archive_url',
#  'archived',
#  'assignees_url',
#  'blobs_url',
#  'branches_url',
#  'clone_url',
#  'collaborators_url',
#  'comments_url',
#  'commits_url',
#  'compare',
#  'compare_url',
#  'contents_url',
#  'contributors_url',
#  'create_check_run',
#  'create_check_suite',
#  'create_deployment',
#  'create_file',
#  'create_fork',
#  'create_git_blob',
#  'create_git_commit',
#  'create_git_ref',
#  'create_git_release',
#  'create_git_tag',
#  'create_git_tag_and_release',
#  'create_git_tree',
#  'create_hook',
#  'create_issue',
#  'create_key',
#  'create_label',
#  'create_milestone',
#  'create_project',
#  'create_pull',
#  'create_repository_dispatch',
#  'create_secret',
#  'create_source_import',
#  'created_at',
#  'default_branch',
#  'delete',
#  'delete_branch_on_merge',
#  'delete_file',
#  'delete_secret',
#  'deployments_url',
#  'description',
#  'disable_automated_security_fixes',
#  'disable_vulnerability_alert',
#  'downloads_url',
#  'edit',
#  'enable_automated_security_fixes',
#  'enable_vulnerability_alert',
#  'etag',
#  'events_url',
#  'fork',
#  'forks',
#  'forks_count',
#  'forks_url',
#  'full_name',
#  'get__repr__',
#  'get_archive_link',
#  'get_assignees',
#  'get_branch',
#  'get_branches',
#  'get_check_run',
#  'get_check_suite',
#  'get_clones_traffic',
#  'get_collaborator_permission',
#  'get_collaborators',
#  'get_comment',
#  'get_comments',
#  'get_commit',
#  'get_commits',
#  'get_contents',
#  'get_contributors',
#  'get_deployment',
#  'get_deployments',
#  'get_dir_contents',
#  'get_download',
#  'get_downloads',
#  'get_events',
#  'get_forks',
#  'get_git_blob',
#  'get_git_commit',
#  'get_git_matching_refs',
#  'get_git_ref',
#  'get_git_refs',
#  'get_git_tag',
#  'get_git_tree',
#  'get_hook',
#  'get_hooks',
#  'get_issue',
#  'get_issues',
#  'get_issues_comments',
#  'get_issues_event',
#  'get_issues_events',
#  'get_key',
#  'get_keys',
#  'get_label',
#  'get_labels',
#  'get_languages',
#  'get_latest_release',
#  'get_license',
#  'get_milestone',
#  'get_milestones',
#  'get_network_events',
#  'get_notifications',
#  'get_pending_invitations',
#  'get_projects',
#  'get_public_key',
#  'get_pull',
#  'get_pulls',
#  'get_pulls_comments',
#  'get_pulls_review_comments',
#  'get_readme',
#  'get_release',
#  'get_release_asset',
#  'get_releases',
#  'get_self_hosted_runner',
#  'get_self_hosted_runners',
#  'get_source_import',
#  'get_stargazers',
#  'get_stargazers_with_dates',
#  'get_stats_code_frequency',
#  'get_stats_commit_activity',
#  'get_stats_contributors',
#  'get_stats_participation',
#  'get_stats_punch_card',
#  'get_subscribers',
#  'get_tags',
#  'get_teams',
#  'get_top_paths',
#  'get_top_referrers',
#  'get_topics',
#  'get_views_traffic',
#  'get_vulnerability_alert',
#  'get_watchers',
#  'get_workflow',
#  'get_workflow_run',
#  'get_workflow_runs',
#  'get_workflows',
#  'git_commits_url',
#  'git_refs_url',
#  'git_tags_url',
#  'git_url',
#  'has_downloads',
#  'has_in_assignees',
#  'has_in_collaborators',
#  'has_issues',
#  'has_pages',
#  'has_projects',
#  'has_wiki',
#  'homepage',
#  'hooks_url',
#  'html_url',
#  'id',
#  'issue_comment_url',
#  'issue_events_url',
#  'issues_url',
#  'keys_url',
#  'labels_url',
#  'language',
#  'languages_url',
#  'last_modified',
#  'legacy_search_issues',
#  'mark_notifications_as_read',
#  'master_branch',
#  'merge',
#  'merges_url',
#  'milestones_url',
#  'mirror_url',
#  'name',
#  'network_count',
#  'notifications_url',
#  'open_issues',
#  'open_issues_count',
#  'organization',
#  'owner',
#  'parent',
#  'permissions',
#  'private',
#  'pulls_url',
#  'pushed_at',
#  'raw_data',
#  'raw_headers',
#  'releases_url',
#  'remove_from_collaborators',
#  'remove_invitation',
#  'remove_self_hosted_runner',
#  'replace_topics',
#  'setCheckAfterInitFlag',
#  'size',
#  'source',
#  'ssh_url',
#  'stargazers_count',
#  'stargazers_url',
#  'statuses_url',
#  'subscribe_to_hub',
#  'subscribers_count',
#  'subscribers_url',
#  'subscription_url',
#  'svn_url',
#  'tags_url',
#  'teams_url',
#  'trees_url',
#  'unsubscribe_from_hub',
#  'update',
#  'update_check_suites_preferences',
#  'update_file',
#  'updated_at',
#  'url',
#  'watchers',
#  'watchers_count']

# %%
tt = t.src
tt
# Out:
# Repository(full_name="i2mint/dol")

# %%
x = tt.get_workflows()

# %%
dir(x)
# Out:
# ['_PaginatedListBase__elements',
#  '_PaginatedListBase__fetchToIndex',
#  '_PaginatedList__contentClass',
#  '_PaginatedList__firstParams',
#  '_PaginatedList__firstUrl',
#  '_PaginatedList__headers',
#  '_PaginatedList__list_item',
#  '_PaginatedList__nextParams',
#  '_PaginatedList__nextUrl',
#  '_PaginatedList__parseLinkHeader',
#  '_PaginatedList__requester',
#  '_PaginatedList__reverse',
#  '_PaginatedList__totalCount',
#  '_Slice',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_couldGrow',
#  '_fetchNextPage',
#  '_getLastPageUrl',
#  '_grow',
#  '_isBiggerThan',
#  '_reversed',
#  'get_page',
#  'reversed',
#  'totalCount']

# %%
x.get_page(0)
# Out:
# [Workflow(url="https://api.github.com/repos/i2mint/dol/actions/workflows/7620695", name="Continuous Integration")]

# %%
tt.get_workflow_runs().get_page(0)
# Out:
# [WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1468971015", id=1468971015),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1464140305", id=1464140305),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1464118067", id=1464118067),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1444958766", id=1444958766),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1442722023", id=1442722023),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1442718941", id=1442718941),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1442143160", id=1442143160),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1441523495", id=1441523495),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1441244973", id=1441244973),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1441122268", id=1441122268),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1441108141", id=1441108141),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1440700547", id=1440700547),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1437307649", id=1437307649),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1338857801", id=1338857801),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1338782876", id=1338782876),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1338756145", id=1338756145),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1330669551", id=1330669551),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1321875805", id=1321875805),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1321854521", id=1321854521),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1321853309", id=1321853309),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1246793199", id=1246793199),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1238874345", id=1238874345),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1211359099", id=1211359099),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1207475184", id=1207475184),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1206841221", id=1206841221),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1206838913", id=1206838913),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1199908408", id=1199908408),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1196324024", id=1196324024),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1183986106", id=1183986106),
#  WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1183922904", id=1183922904)]

# %%
w = tt.get_workflow_run(1468971015)
w
# Out:
# WorkflowRun(url="https://api.github.com/repos/i2mint/dol/actions/runs/1468971015", id=1468971015)

# %%
w.conclusion
# Out:
# 'success'

# %%
# Out:
# True

# %% [markdown]
# # A one cell demo

# %% [markdown]
# # Talking to github
#
# The first few here don't require the github python package. Just `requests`.
#
# But they do require a token (e.g. in environment variable `GITHUB_TOKEN`).
#
# ```python
# import pandas as pd
# ```
#
# ## Get repositories list
#
# ```python
# from hubcap.examples import repos_info, actions_info
# otosense = repos_info('otosense')
# i2mint = repos_info('i2mint')
# ```
#
# ## check if most recently changed repositories' CI failed or not
#
# ```python
# repos = i2mint
# updated_recently = repos.iloc[date_selection_lidx(repos, hours_ago=24 * 365)]
# i2mint_cis = {repo: get_last_build_status(repo) for repo in updated_recently['full_name']}
# pd.Series(i2mint_cis)
# ```
#
# ```python
# repos = otosense
# updated_recently = repos.iloc[date_selection_lidx(repos, hours_ago=24 * 365)]
# i2mint_cis = {repo: get_last_build_status(repo) for repo in updated_recently['full_name']}
# pd.Series(i2mint_cis)
# ```
#
#
#
# ## See recently updated repos
#
# ```python
# repos = i2mint
#
# from hubcap.examples import date_selection_lidx, get_last_build_status
#
# updated_recently = repos.iloc[date_selection_lidx(repos, hours_ago=24 * 2)]
# updated_recently
# ```
#
# ## See actions status of repository
#
# ```python
# actions_info('otosense/recode')
# ```
#
#
#
# ## with github python package
#
# ```python
# from hubcap import GitHubReader
#
# s = GitHubReader('i2mint', login_or_token=os.environ['GITHUB_TOKEN'])
# list(s)
#
# t = s['dol']
# list(t)
#
# t['master']
#
# dir(t.src)
#
# tt = t.src
# tt
#
# x = tt.get_workflows()
#
# dir(x)
#
# x.get_page(0)
#
# tt.get_workflow_runs().get_page(0)
#
# w = tt.get_workflow_run(1468971015)
# w
#
# w.conclusion
#
# w.rerun()
# ```
